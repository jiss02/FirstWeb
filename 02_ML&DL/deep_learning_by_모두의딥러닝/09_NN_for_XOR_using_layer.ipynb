# %%
import tensorflow as tf

# %%
import numpy as np

# %%
x_data = np.array([[0,0],[0,1],[1,0],[1,1]], dtype = np.float32)
y_data = np.array([[0],[1],[1],[0]], dtype = np.float32)

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

# 중간 단계의 아웃풋 숫자는 우리가 정해주면 된다.
W1 = tf.Variable(tf.random_normal([2,3]), name = "weight")
b1 = tf.Variable(tf.random_normal([3]), name = "bias") # 아웃의 수와 같다.
layer1 = tf.sigmoid(tf.matmul(X, W1)+b1)

W2 = tf.Variable(tf.random_normal([3,1]), name = "weight")
b2 = tf.Variable(tf.random_normal([1]), name = "bias")
hy = tf.sigmoid(tf.matmul(layer1, W2)+b2)

# %%
cost = -tf.reduce_mean(Y*tf.log(hy) + (1-Y)*tf.log(1-hy))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
predicted = tf.cast(hy > 0.5, dtype = tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train, feed_dict={X: x_data, Y : y_data})
        
        if step % 100 ==0:
            print(step, sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run([W1,W2]))
            


    h, c, a = sess.run(
              [hy, predicted, accuracy], feed_dict={X: x_data, Y: y_data}
    )
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
  
# 성능이 너무나 구리다.
# Out:
# 0 0.75156367 [array([[-1.7504237 ,  1.0366925 ,  0.14596562],
#        [ 0.8349995 , -1.2237933 , -0.03409995]], dtype=float32), array([[-1.7760369 ],
#        [ 0.43013227],
#        [-0.749446  ]], dtype=float32)]
# 100 0.70959944 [array([[-1.7049098 ,  0.97260267,  0.14726211],
#        [ 0.4813014 , -1.1989237 , -0.05765435]], dtype=float32), array([[-1.6113862 ],
#        [ 0.46721214],
#        [-0.68131196]], dtype=float32)]
# 200 0.701354 [array([[-1.6798158 ,  0.9130769 ,  0.15952522],
#        [ 0.24618219, -1.1983479 , -0.05760901]], dtype=float32), array([[-1.5450743 ],
#        [ 0.37485927],
#        [-0.67610085]], dtype=float32)]
# 300 0.69668156 [array([[-1.6688002 ,  0.86894274,  0.16865194],
#        [ 0.06074081, -1.2032412 , -0.05292342]], dtype=float32), array([[-1.5139086 ],
#        [ 0.30350918],
#        [-0.67198133]], dtype=float32)]
# 400 0.69360656 [array([[-1.666378  ,  0.83560187,  0.17612518],
# ...
