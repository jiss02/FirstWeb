# %%
import tensorflow as tf

# %%
import numpy as np

# %%
x_data = np.array([[0,0],[0,1],[1,0],[1,1]], dtype = np.float32)
y_data = np.array([[0],[1],[1],[0]], dtype = np.float32)

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
W = tf.Variable(tf.random_normal([2,1]), name = "weight")
b = tf.Variable(tf.random_normal([1]), name = "bias") # 아웃의 수와 같다.
# Out:
# WARNING:tensorflow:From C:\Users\olo51\Anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
hy = tf.sigmoid(tf.matmul(X, W)+b)

# %%
cost = -tf.reduce_mean(Y*tf.log(hy) + (1-Y)*tf.log(1-hy))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\olo51\Anaconda3\envs\tensor\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
predicted = tf.cast(hy > 0.5, dtype = tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train, feed_dict={X: x_data, Y : y_data})
        
        if step % 100 ==0:
            print(step, sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run(W))
            


    h, c, a = sess.run(
              [hy, predicted, accuracy], feed_dict={X: x_data, Y: y_data}
    )
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
  
# 성능이 너무나 구리다.
# Out:
# 0 0.8146241 [[0.88603836]
#  [0.09854405]]
# 100 0.69669646 [[ 0.31861532]
#  [-0.11066873]]
# 200 0.69425917 [[ 0.18063039]
#  [-0.04902025]]
# 300 0.69351393 [[ 0.10571732]
#  [-0.01701552]]
# 400 0.69327426 [[ 0.06272355]
#  [-0.00284979]]
# 500 0.6931937 [[0.03772273]
#  [0.00269137]]
# 600 0.6931651 [[0.02299645]
#  [0.00428205]]
# 700 0.6931544 [[0.0142048 ]
#  [0.00420731]]
# 800 0.6931503 [[0.00888417]
#  [0.00354337]]
# 900 0.69314843 [[0.00562064]
#  [0.00276752]]
# 1000 0.6931477 [[0.00359295]
#  [0.00206877]]
# 1100 0.6931474 [[0.00231783]
#  [0.0015036 ]]
# 1200 0.6931473 [[0.00150716]
#  [0.0010722 ]]
# 1300 0.6931472 [[0.00098667]
#  [0.00075432]]
# 1400 0.6931472 [[0.00064956]
#  [0.00052545]]
# 1500 0.6931471 [[0.00042975]
#  [0.00036345]]
# 1600 0.6931472 [[0.0002854 ]
#  [0.00024998]]
# 1700 0.6931472 [[0.00019012]
#  [0.0001712 ]]
# 1800 0.6931472 [[0.00012698]
#  [0.00011688]]
# 1900 0.6931472 [[8.500054e-05]
#  [7.959656e-05]]
# 2000 0.69314724 [[5.6986355e-05]
#  [5.4097720e-05]]
# 2100 0.6931472 [[3.8249644e-05]
#  [3.6709564e-05]]
# 2200 0.6931472 [[2.5702870e-05]
#  [2.4882502e-05]]
# 2300 0.6931471 [[1.7283714e-05]
#  [1.6843329e-05]]
# 2400 0.6931472 [[1.1631701e-05]
#  [1.1396955e-05]]
# 2500 0.6931471 [[7.821478e-06]
#  [7.701468e-06]]
# 2600 0.6931472 [[5.258480e-06]
#  [5.201052e-06]]
# 2700 0.6931472 [[3.5522930e-06]
#  [3.5216885e-06]]
# 2800 0.6931472 [[2.3870227e-06]
#  [2.3728105e-06]]
# 2900 0.6931472 [[1.6121603e-06]
#  [1.6113589e-06]]
# 3000 0.6931472 [[1.0861460e-06]
#  [1.0853446e-06]]
# 3100 0.6931471 [[7.195763e-07]
#  [7.187749e-07]]
# 3200 0.6931472 [[4.7221693e-07]
#  [4.7141555e-07]]
# 3300 0.6931472 [[3.2320474e-07]
#  [3.2240337e-07]]
# 3400 0.6931472 [[2.0101476e-07]
#  [2.0021338e-07]]
# 3500 0.6931472 [[1.4737037e-07]
#  [1.4656899e-07]]
# 3600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 3700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 3800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 3900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4100 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4200 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4300 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4400 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4500 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 4900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5100 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5200 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5300 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5400 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5500 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 5900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6100 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6200 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6300 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6400 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6500 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 6900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7100 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7200 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7300 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7400 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7500 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 7900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8100 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8200 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8300 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8400 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8500 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 8900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9100 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9200 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9300 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9400 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9500 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9600 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9700 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9800 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 9900 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
# 10000 0.6931472 [[1.3395928e-07]
#  [1.3315790e-07]]
#
# Hypothesis:  [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]]
# Correct:  [[0.]
#  [0.]
#  [0.]
#  [0.]]
# Accuracy:  0.5
